# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

#generate 100 
x_data = np.random.rand(100)
noise = np.random.rand(100)*0.1
y_data = x_data*0.8 + 0.2 + noise


plt.scatter(x_data, y_data)
plt.show()

# %%
b = tf.Variable(0.)
k = tf.Variable(0.)
y = k * x_data + b

#二次代价函数
loss = tf.reduce_mean(tf.square(y_data - y))

#optimizor
optimizor = tf.train.GradientDescentOptimizer(0.2)

#最小化代价函数
train = optimizor.minimize(loss)

init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for step in range(2001):
        sess.run(train)
        if(step%20 == 0):
            print(step, sess.run([k, b]))
# Out:
# 0 [0.15013544, 0.25472695]
# 20 [0.495468, 0.40557572]
# 40 [0.61947066, 0.34094623]
# 60 [0.6927845, 0.30273527]
# 80 [0.73612976, 0.28014386]
# 100 [0.76175684, 0.26678714]
# 120 [0.7769083, 0.25889024]
# 140 [0.7858663, 0.25422135]
# 160 [0.79116255, 0.25146097]
# 180 [0.7942938, 0.24982893]
# 200 [0.7961452, 0.24886402]
# 220 [0.7972397, 0.24829355]
# 240 [0.79788685, 0.24795626]
# 260 [0.7982694, 0.2477569]
# 280 [0.7984956, 0.24763899]
# 300 [0.79862934, 0.24756928]
# 320 [0.7987084, 0.24752809]
# 340 [0.7987551, 0.24750374]
# 360 [0.79878277, 0.24748932]
# 380 [0.79879916, 0.2474808]
# 400 [0.7988088, 0.24747573]
# 420 [0.79881454, 0.24747278]
# 440 [0.7988178, 0.24747105]
# 460 [0.79881984, 0.24746999]
# 480 [0.79882103, 0.2474694]
# 500 [0.79882187, 0.24746895]
# 520 [0.7988219, 0.2474689]
# 540 [0.7988219, 0.2474689]
# 560 [0.7988219, 0.2474689]
# 580 [0.7988219, 0.2474689]
# 600 [0.7988219, 0.2474689]
# 620 [0.7988219, 0.2474689]
# 640 [0.7988219, 0.2474689]
# 660 [0.7988219, 0.2474689]
# 680 [0.7988219, 0.2474689]
# 700 [0.7988219, 0.2474689]
# 720 [0.7988219, 0.2474689]
# 740 [0.7988219, 0.2474689]
# 760 [0.7988219, 0.2474689]
# 780 [0.7988219, 0.2474689]
# 800 [0.7988219, 0.2474689]
# 820 [0.7988219, 0.2474689]
# 840 [0.7988219, 0.2474689]
# 860 [0.7988219, 0.2474689]
# 880 [0.7988219, 0.2474689]
# 900 [0.7988219, 0.2474689]
# 920 [0.7988219, 0.2474689]
# 940 [0.7988219, 0.2474689]
# 960 [0.7988219, 0.2474689]
# 980 [0.7988219, 0.2474689]
# 1000 [0.7988219, 0.2474689]
# 1020 [0.7988219, 0.2474689]
# 1040 [0.7988219, 0.2474689]
# 1060 [0.7988219, 0.2474689]
# 1080 [0.7988219, 0.2474689]
# 1100 [0.7988219, 0.2474689]
# 1120 [0.7988219, 0.2474689]
# 1140 [0.7988219, 0.2474689]
# 1160 [0.7988219, 0.2474689]
# 1180 [0.7988219, 0.2474689]
# 1200 [0.7988219, 0.2474689]
# 1220 [0.7988219, 0.2474689]
# 1240 [0.7988219, 0.2474689]
# 1260 [0.7988219, 0.2474689]
# 1280 [0.7988219, 0.2474689]
# 1300 [0.7988219, 0.2474689]
# 1320 [0.7988219, 0.2474689]
# 1340 [0.7988219, 0.2474689]
# 1360 [0.7988219, 0.2474689]
# 1380 [0.7988219, 0.2474689]
# 1400 [0.7988219, 0.2474689]
# 1420 [0.7988219, 0.2474689]
# 1440 [0.7988219, 0.2474689]
# 1460 [0.7988219, 0.2474689]
# 1480 [0.7988219, 0.2474689]
# 1500 [0.7988219, 0.2474689]
# 1520 [0.7988219, 0.2474689]
# 1540 [0.7988219, 0.2474689]
# 1560 [0.7988219, 0.2474689]
# 1580 [0.7988219, 0.2474689]
# 1600 [0.7988219, 0.2474689]
# 1620 [0.7988219, 0.2474689]
# 1640 [0.7988219, 0.2474689]
# 1660 [0.7988219, 0.2474689]
# 1680 [0.7988219, 0.2474689]
# 1700 [0.7988219, 0.2474689]
# 1720 [0.7988219, 0.2474689]
# 1740 [0.7988219, 0.2474689]
# 1760 [0.7988219, 0.2474689]
# 1780 [0.7988219, 0.2474689]
# 1800 [0.7988219, 0.2474689]
# 1820 [0.7988219, 0.2474689]
# 1840 [0.7988219, 0.2474689]
# 1860 [0.7988219, 0.2474689]
# 1880 [0.7988219, 0.2474689]
# 1900 [0.7988219, 0.2474689]
# 1920 [0.7988219, 0.2474689]
# 1940 [0.7988219, 0.2474689]
# 1960 [0.7988219, 0.2474689]
# 1980 [0.7988219, 0.2474689]
# 2000 [0.7988219, 0.2474689]
